# %% [markdown]
# > **Evaluation**
# > ---
#
# This file is used to check the evaluation results for the train set

# %% [markdown]
# ## Setup

# %% [markdown]
# Setting up workspace

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os

# root_dir = # "PATH_TO_YOUR_FOLDER"
data_dir = os.path.join(root_dir, "project_data")

os.chdir(root_dir)
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /content/drive/My Drive/03 Ewha Exchange/05 computer vision/group project final

# %%
# !git clone https://github.com/ewha-pai/cv_project_tools.git

# %%
# %cd cv_project_tools
# Out:
# /content/drive/My Drive/03 Ewha Exchange/05 computer vision/group project final/cv_project_tools

# %%
# !python setup.py build_ext --inplace

# %%
import numpy as np
from tqdm import tqdm

from core.dataset import BoundaryDataset
from core import evaluate_boundaries

# %% [markdown]
# Loading train images dataset

# %%
split = 'train'

dataset = BoundaryDataset(root_dir + "/project_data", split=split)

print(f"Data size: {len(dataset)}")
# Out:
# Data size: 200

# %% [markdown]
# Loading prediction npy file

# %%
# Load the saved predictions
predictions = np.load(os.path.join(root_dir, 'predictions_train.npy'), allow_pickle=True).item()

# Function to load the prediction for a given sample name
def load_pred(sample_name):
    # Retrieve the prediction for the given sample name from the loaded dictionary
    if sample_name in predictions:
        pred = predictions[sample_name]
        return pred
    else:
        raise KeyError(f"Sample '{sample_name}' not found in the predictions.")

# %% [markdown]
# ## Primary Evaluation using first 10 images

# %%
thresholds = 20
apply_thinning = True

sample_names = dataset.sample_names[:10]

sample_results, threshold_results, best_result_single, best_result = evaluate_boundaries.pr_evaluation(
    thresholds, sample_names, dataset.load_boundaries, load_pred, apply_thinning=apply_thinning, progress=tqdm
)
# Out:
# Processing samples: 100%|██████████| 10/10 [03:10<00:00, 19.07s/it]

# %% [markdown]
# To calculate your final score, the following two F1 scores will be averaged:
# - F1 score using the best threshold for each individual image.
# - F1 score using the single best threshold for all images.

# %%
print('{:<16}: {:<10.6f}'.format('Best F1', best_result.f1))
print('{:<16}: {:<10.6f}'.format('Best F1 (Single)', best_result_single.f1))
# Out:
# Best F1         : 0.653369
# Best F1 (Single): 0.631434

# %% [markdown]
# Overall Evaluation Metrics Using the Best Threshold for Each Image

# %%
print('[Overall Results]')
print('{:<10} {:<10} {:<10} {:<10}'.format('Recall', 'Precision', 'F1-Score', 'Area PR'))
print('{:<10.6f} {:<10.6f} {:<10.6f} {:<10.6f}'.format(
    best_result.recall, best_result.precision, best_result.f1, best_result.area_pr)
)
# Out:
# [Overall Results]
# Recall     Precision  F1-Score   Area PR
# 0.718139   0.599315   0.653369   0.598652

# %% [markdown]
# Overall Evaluation Metrics Using a Single Best Threshold for All Images

# %%
print('[Overall Results using Single Threshold]')
print('{:<10} {:<10} {:<10} {:<10}'.format('Threshold', 'Recall', 'Precision', 'F1-Score'))
print('{:<10.6f} {:<10.6f} {:<10.6f} {:<10.6f}'.format(
    best_result_single.threshold, best_result_single.recall, best_result_single.precision, best_result_single.f1)
)
# Out:
# [Overall Results using Single Threshold]
# Threshold  Recall     Precision  F1-Score
# 0.380952   0.675942   0.592425   0.631434

# %% [markdown]
# Evaluation Results Per Image

# %%
print('[Results Per Image]')
print('{:<10} {:<10} {:<10} {:<10} {:<10}'.format('ID', 'Threshold', 'Recall', 'Precision', 'F1-Score'))
for sample_index, res in enumerate(sample_results):
    print('{:<10s} {:<10.6f} {:<10.6f} {:<10.6f} {:<10.6f}'.format(
        res.sample_name, res.threshold, res.recall, res.precision, res.f1))
# Out:
# [Results Per Image]
# ID         Threshold  Recall     Precision  F1-Score
# 37073      0.333333   0.803165   0.711030   0.754295
# 140055     0.285714   0.643748   0.399757   0.493227
# 118035     0.380952   0.769609   0.826945   0.797247
# 159008     0.333333   0.615313   0.456428   0.524093
# 78019      0.285714   0.776323   0.482823   0.595367
# 314016     0.333333   0.764706   0.647781   0.701404
# 254033     0.571429   0.362343   0.304243   0.330761
# 189080     0.333333   0.700785   0.748637   0.723921
# 8049       0.523810   0.805696   0.889782   0.845654
# 12003      0.428571   0.753671   0.703286   0.727607

# %% [markdown]
# Evaluation Results Per Threshold

# %%
print('[Results Per Threshold]')
print('{:<10} {:<10} {:<10} {:<10}'.format('Threshold', 'Recall', 'Precision', 'F1-Score'))
for thresh_i, res in enumerate(threshold_results):
    print('{:<10.6f} {:<10.6f} {:<10.6f} {:<10.6f}'.format(
        res.threshold, res.recall, res.precision, res.f1))
# Out:
# [Results Per Threshold]
# Threshold  Recall     Precision  F1-Score
# 0.047619   0.823757   0.215383   0.341481
# 0.095238   0.879792   0.264079   0.406225
# 0.142857   0.887145   0.324193   0.474857
# 0.190476   0.871942   0.386209   0.535313
# 0.238095   0.837121   0.444191   0.580408
# 0.285714   0.789364   0.500357   0.612480
# 0.333333   0.733723   0.548160   0.627510
# 0.380952   0.675942   0.592425   0.631434
# 0.428571   0.618139   0.634570   0.626247
# 0.476190   0.559260   0.669744   0.609536
# 0.523810   0.504555   0.704095   0.587853
# 0.571429   0.451179   0.738735   0.560212
# 0.619048   0.396451   0.766329   0.522561
# 0.666667   0.348266   0.786245   0.482714
# 0.714286   0.300983   0.803087   0.437862
# 0.761905   0.251642   0.817083   0.384780
# 0.809524   0.199850   0.831750   0.322266
# 0.857143   0.142416   0.819709   0.242671
# 0.904762   0.057445   0.833194   0.107480
# 0.952381   0.013584   0.815254   0.026722

# %% [markdown]
# ## Evaluation using all images

# %%
thresholds = 20
apply_thinning = True

sample_names = dataset.sample_names

sample_results, threshold_results, best_result_single, best_result = evaluate_boundaries.pr_evaluation(
    thresholds, sample_names, dataset.load_boundaries, load_pred, apply_thinning=apply_thinning, progress=tqdm
)
# Out:
# Processing samples: 100%|██████████| 200/200 [50:14<00:00, 15.07s/it]

# %% [markdown]
# To calculate your final score, the following two F1 scores will be averaged:
# - F1 score using the best threshold for each individual image.
# - F1 score using the single best threshold for all images.

# %%
print('{:<16}: {:<10.6f}'.format('Best F1', best_result.f1))
print('{:<16}: {:<10.6f}'.format('Best F1 (Single)', best_result_single.f1))
# Out:
# Best F1         : 0.585329
# Best F1 (Single): 0.558811

# %% [markdown]
# Overall Evaluation Metrics Using the Best Threshold for Each Image

# %%
print('[Overall Results]')
print('{:<10} {:<10} {:<10} {:<10}'.format('Recall', 'Precision', 'F1-Score', 'Area PR'))
print('{:<10.6f} {:<10.6f} {:<10.6f} {:<10.6f}'.format(
    best_result.recall, best_result.precision, best_result.f1, best_result.area_pr)
)
# Out:
# [Overall Results]
# Recall     Precision  F1-Score   Area PR
# 0.673192   0.517754   0.585329   0.506729

# %% [markdown]
# Overall Evaluation Metrics Using a Single Best Threshold for All Images

# %%
print('[Overall Results using Single Threshold]')
print('{:<10} {:<10} {:<10} {:<10}'.format('Threshold', 'Recall', 'Precision', 'F1-Score'))
print('{:<10.6f} {:<10.6f} {:<10.6f} {:<10.6f}'.format(
    best_result_single.threshold, best_result_single.recall, best_result_single.precision, best_result_single.f1)
)
# Out:
# [Overall Results using Single Threshold]
# Threshold  Recall     Precision  F1-Score
# 0.380952   0.615178   0.511906   0.558811

# %% [markdown]
# Evaluation Results Per Image

# %%
print('[Results Per Image]')
print('{:<10} {:<10} {:<10} {:<10} {:<10}'.format('ID', 'Threshold', 'Recall', 'Precision', 'F1-Score'))
for sample_index, res in enumerate(sample_results):
    print('{:<10s} {:<10.6f} {:<10.6f} {:<10.6f} {:<10.6f}'.format(
        res.sample_name, res.threshold, res.recall, res.precision, res.f1))
# Out:
# [Results Per Image]
# ID         Threshold  Recall     Precision  F1-Score
# 37073      0.333333   0.802942   0.710865   0.754104
# 140055     0.285714   0.643748   0.399583   0.493095
# 118035     0.380952   0.769363   0.826945   0.797115
# 159008     0.333333   0.615313   0.456110   0.523883
# 78019      0.285714   0.776393   0.483759   0.596098
# 314016     0.333333   0.764961   0.647566   0.701385
# 254033     0.571429   0.362343   0.304644   0.330997
# 189080     0.285714   0.741412   0.706993   0.723794
# 8049       0.523810   0.805794   0.890371   0.845974
# 12003      0.428571   0.753557   0.703092   0.727450
# 159091     0.476190   0.690040   0.628788   0.657991
# 71046      0.380952   0.715615   0.636364   0.673667
# 59078      0.428571   0.548759   0.623219   0.583623
# 2092       0.333333   0.782979   0.680518   0.728161
# 208001     0.190476   0.713926   0.422140   0.530562
# 232038     0.285714   0.698475   0.588376   0.638716
# 188063     0.285714   0.617951   0.391222   0.479117
# 126007     0.285714   0.668291   0.426497   0.520693
# 42078      0.428571   0.746693   0.732663   0.739611
# 374067     0.333333   0.507563   0.711036   0.592312
# 122048     0.619048   0.578566   0.513311   0.543988
# 304074     0.428571   0.579474   0.568726   0.574050
# 65132      0.380952   0.420192   0.324909   0.366458
# 271008     0.380952   0.732739   0.617450   0.670172
# 45096      0.380952   0.694076   0.693167   0.693621
# 157055     0.380952   0.704803   0.579651   0.636130
# 65019      0.380952   0.823808   0.668724   0.738209
# 147021     0.380952   0.443309   0.518579   0.477999
# 113009     0.428571   0.726800   0.775453   0.750339
# 113016     0.476190   0.640360   0.809005   0.714871
# 368078     0.285714   0.849527   0.502751   0.631676
# 216066     0.428571   0.594147   0.446501   0.509850
# 160068     0.523810   0.593209   0.337549   0.430267
# 23025      0.285714   0.745276   0.525870   0.616637
# 372047     0.190476   0.853331   0.525944   0.650783
# 55067      0.142857   0.859811   0.741945   0.796541
# 108070     0.428571   0.339821   0.216420   0.264432
# 78004      0.428571   0.549791   0.684067   0.609623
# 249087     0.380952   0.600451   0.517287   0.555775
# 385039     0.142857   0.789879   0.404153   0.534712
# 112082     0.333333   0.599607   0.360536   0.450308
# 167062     0.523810   0.957676   0.905882   0.931060
# 100098     0.428571   0.810581   0.803846   0.807200
# 304034     0.476190   0.432543   0.318604   0.366932
# 238011     0.476190   0.939581   0.972409   0.955713
# 76002      0.380952   0.721590   0.749062   0.735069
# 166081     0.380952   0.624976   0.655591   0.639918
# 94079      0.380952   0.629661   0.291656   0.398657
# 285079     0.428571   0.634370   0.671658   0.652481
# 106020     0.190476   0.773150   0.208755   0.328746
# 353013     0.571429   0.731127   0.591650   0.654035
# 302003     0.285714   0.811572   0.745503   0.777136
# 24004      0.333333   0.635519   0.539328   0.583486
# 106025     0.285714   0.477617   0.879786   0.619125
# 198054     0.142857   0.887016   0.383227   0.535218
# 231015     0.380952   0.753920   0.571189   0.649955
# 301007     0.285714   0.787406   0.561763   0.655716
# 130026     0.523810   0.410351   0.408113   0.409229
# 35058      0.190476   0.705809   0.282975   0.403984
# 54082      0.285714   0.688483   0.435887   0.533811
# 65033      0.333333   0.610818   0.585596   0.597941
# 12084      0.476190   0.774519   0.297624   0.430009
# 181091     0.428571   0.563577   0.668790   0.611692
# 268002     0.380952   0.619794   0.424047   0.503567
# 156079     0.333333   0.669289   0.569289   0.615252
# 22013      0.380952   0.608492   0.407903   0.488404
# 370036     0.380952   0.775069   0.626010   0.692610
# 145086     0.380952   0.845514   0.898315   0.871115
# 249061     0.285714   0.766112   0.478303   0.588925
# 176039     0.571429   0.587376   0.683924   0.631984
# 33039      0.380952   0.680437   0.352698   0.464583
# 246053     0.285714   0.551904   0.619927   0.583941
# 182053     0.428571   0.664196   0.629190   0.646219
# 134035     0.523810   0.518455   0.369425   0.431432
# 15088      0.523810   0.745237   0.443655   0.556196
# 299091     0.285714   0.421600   0.564082   0.482543
# 300091     0.333333   0.796071   0.568583   0.663366
# 253027     0.476190   0.808296   0.700310   0.750438
# 210088     0.285714   0.682070   0.435961   0.531928
# 239007     0.285714   0.659417   0.701977   0.680032
# 135069     0.380952   0.981762   0.966080   0.973858
# 117054     0.380952   0.624511   0.505541   0.558763
# 169012     0.571429   0.313811   0.331073   0.322211
# 159029     0.476190   0.374775   0.434355   0.402371
# 12074      0.523810   0.739824   0.574451   0.646733
# 196073     0.476190   0.673280   0.493721   0.569687
# 65074      0.285714   0.770279   0.600175   0.674670
# 54005      0.428571   0.595796   0.613147   0.604347
# 41033      0.428571   0.624979   0.654171   0.639242
# 351093     0.380952   0.670217   0.597795   0.631938
# 271035     0.333333   0.793826   0.474195   0.593726
# 187029     0.428571   0.555574   0.628187   0.589653
# 198023     0.523810   0.540351   0.877539   0.668852
# 365025     0.190476   0.471971   0.488861   0.480268
# 100080     0.047619   0.827898   0.329294   0.471179
# 41004      0.523810   0.754157   0.851372   0.799821
# 76053      0.333333   0.408411   0.430054   0.418953
# 69020      0.333333   0.591129   0.547578   0.568521
# 229036     0.476190   0.629192   0.561628   0.593493
# 163062     0.428571   0.407898   0.518102   0.456442
# 376020     0.333333   0.651267   0.501991   0.566968
# 21077      0.476190   0.708172   0.516507   0.597341
# 22090      0.190476   0.676944   0.666505   0.671684
# 311081     0.523810   0.365524   0.611940   0.457672
# 42012      0.380952   0.505689   0.554855   0.529132
# 242078     0.476190   0.752696   0.463101   0.573409
# 310007     0.428571   0.775424   0.537807   0.635118
# 153093     0.333333   0.676774   0.689818   0.683233
# 22093      0.285714   0.874524   0.692207   0.772757
# 163085     0.333333   0.640794   0.215294   0.322301
# 295087     0.333333   0.664931   0.591581   0.626115
# 145053     0.380952   0.720971   0.501876   0.591796
# 103041     0.476190   0.453863   0.346435   0.392939
# 135037     0.095238   0.795236   0.259943   0.391812
# 101087     0.238095   0.775234   0.676587   0.722559
# 247085     0.380952   0.553569   0.446365   0.494220
# 80099      0.285714   0.486095   0.363699   0.416083
# 15004      0.333333   0.639860   0.410437   0.500092
# 28075      0.428571   0.747404   0.818673   0.781417
# 61086      0.523810   0.539424   0.357547   0.430046
# 253055     0.285714   0.674233   0.657303   0.665661
# 87046      0.285714   0.649076   0.432601   0.519177
# 55075      0.238095   0.564842   0.666983   0.611678
# 66053      0.285714   0.585935   0.454760   0.512080
# 105053     0.333333   0.522483   0.533684   0.528024
# 161062     0.380952   0.811560   0.480937   0.603961
# 225017     0.476190   0.673700   0.432325   0.526674
# 143090     0.238095   0.796128   0.601165   0.685045
# 187039     0.333333   0.750246   0.270045   0.397142
# 183055     0.380952   0.756775   0.588320   0.661999
# 227040     0.380952   0.720945   0.584392   0.645526
# 293029     0.380952   0.532229   0.465626   0.496705
# 376001     0.333333   0.717599   0.666174   0.690931
# 209070     0.333333   0.692646   0.585642   0.634666
# 260081     0.285714   0.583834   0.252772   0.352799
# 118020     0.380952   0.554339   0.448584   0.495886
# 220075     0.285714   0.639980   0.496143   0.558956
# 23084      0.380952   0.493320   0.468903   0.480801
# 108073     0.476190   0.534613   0.515702   0.524987
# 89072      0.333333   0.671211   0.304786   0.419214
# 138078     0.380952   0.809917   0.681583   0.740229
# 164074     0.380952   0.480350   0.156808   0.236433
# 134008     0.380952   0.669233   0.195597   0.302718
# 157036     0.380952   0.808013   0.329914   0.468527
# 365073     0.380952   0.719957   0.535080   0.613902
# 163014     0.476190   0.643812   0.507567   0.567628
# 187083     0.380952   0.577583   0.463987   0.514590
# 108041     0.238095   0.615269   0.263854   0.369325
# 374020     0.238095   0.761488   0.435001   0.553700
# 202012     0.428571   0.697279   0.564505   0.623906
# 227046     0.428571   0.656706   0.574419   0.612812
# 42049      0.428571   0.915869   0.930513   0.923133
# 20008      0.285714   0.546847   0.348060   0.425375
# 296007     0.285714   0.736138   0.601720   0.662177
# 271031     0.476190   0.621212   0.874824   0.726522
# 296059     0.333333   0.808956   0.897881   0.851102
# 361084     0.380952   0.829983   0.868198   0.848660
# 16077      0.380952   0.587637   0.457933   0.514740
# 181018     0.285714   0.604996   0.590866   0.597847
# 45077      0.380952   0.504804   0.541066   0.522306
# 311068     0.380952   0.440215   0.543980   0.486628
# 65010      0.333333   0.699069   0.617536   0.655778
# 126039     0.190476   0.582791   0.634965   0.607761
# 236017     0.333333   0.528537   0.354651   0.424476
# 62096      0.714286   0.658111   0.936301   0.772937
# 55073      0.285714   0.634192   0.421987   0.506772
# 43070      0.380952   0.503268   0.475728   0.489111
# 69040      0.047619   0.758238   0.292938   0.422606
# 189003     0.333333   0.734668   0.381798   0.502469
# 104022     0.428571   0.649320   0.705075   0.676049
# 145014     0.428571   0.484580   0.420874   0.450486
# 159045     0.333333   0.732826   0.537281   0.620000
# 66039      0.476190   0.426471   0.536842   0.475333
# 207056     0.285714   0.834045   0.549498   0.662511
# 246016     0.238095   0.770572   0.514118   0.616748
# 109034     0.380952   0.533144   0.297209   0.381658
# 178054     0.523810   0.573135   0.912748   0.704131
# 241004     0.238095   0.746228   0.607849   0.669968
# 388016     0.238095   0.707564   0.675313   0.691062
# 90076      0.333333   0.740372   0.561061   0.638364
# 253036     0.238095   0.910940   0.888124   0.899387
# 92059      0.428571   0.478683   0.615599   0.538576
# 189011     0.333333   0.546223   0.588373   0.566515
# 147062     0.428571   0.659658   0.541760   0.594924
# 106024     0.285714   0.488881   0.807994   0.609177
# 148089     0.333333   0.655364   0.412099   0.506013
# 35010      0.380952   0.764256   0.841833   0.801171
# 109053     0.285714   0.610703   0.361133   0.453873
# 368016     0.190476   0.877754   0.592333   0.707336
# 28096      0.285714   0.764228   0.235682   0.360262
# 46076      0.190476   0.715023   0.664184   0.688667
# 105025     0.428571   0.477701   0.469593   0.473612
# 147091     0.476190   0.809559   0.782875   0.795993
# 27059      0.285714   0.726338   0.717061   0.721670
# 41025      0.428571   0.660519   0.610051   0.634282
# 385028     0.380952   0.625829   0.670218   0.647263
# 216081     0.285714   0.719724   0.782464   0.749784
# 48055      0.428571   0.516980   0.494995   0.505749
# 130034     0.428571   0.410910   0.310078   0.353443
# 239096     0.190476   0.673898   0.383107   0.488503

# %% [markdown]
# Evaluation Results Per Threshold

# %%
print('[Results Per Threshold]')
print('{:<10} {:<10} {:<10} {:<10}'.format('Threshold', 'Recall', 'Precision', 'F1-Score'))
for thresh_i, res in enumerate(threshold_results):
    print('{:<10.6f} {:<10.6f} {:<10.6f} {:<10.6f}'.format(
        res.threshold, res.recall, res.precision, res.f1))
# Out:
# [Results Per Threshold]
# Threshold  Recall     Precision  F1-Score
# 0.047619   0.814186   0.183281   0.299208
# 0.095238   0.879992   0.213043   0.343038
# 0.142857   0.872778   0.254836   0.394489
# 0.190476   0.840265   0.304049   0.446524
# 0.238095   0.792374   0.356133   0.491404
# 0.285714   0.738133   0.409374   0.526659
# 0.333333   0.677125   0.461103   0.548615
# 0.380952   0.615178   0.511906   0.558811
# 0.428571   0.552673   0.558042   0.555344
# 0.476190   0.492318   0.600476   0.541045
# 0.523810   0.433901   0.636298   0.515961
# 0.571429   0.376027   0.666277   0.480739
# 0.619048   0.320271   0.690708   0.437623
# 0.666667   0.269389   0.711758   0.390848
# 0.714286   0.221309   0.729918   0.339640
# 0.761905   0.176778   0.744271   0.285698
# 0.809524   0.134743   0.755742   0.228709
# 0.857143   0.095561   0.762936   0.169847
# 0.904762   0.050831   0.775582   0.095409
# 0.952381   0.016034   0.809278   0.031444
